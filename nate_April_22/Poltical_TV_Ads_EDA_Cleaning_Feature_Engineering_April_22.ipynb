# %% [markdown]
# # Political TV Ads Initial EDA | Cleaning | Feature Engineering

# %%
import pprint
import pickle
import csv
import pandas as pd
from datetime import datetime
import numpy as np
import string
from collections import Counter
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

pd.set_option("display.max_columns", 2000)
pd.set_option("display.max_rows", 2000)
# pd.set_option("display.precision", 2)
pd.options.display.float_format = '{:,.2f}'.format # this is superior to precision - b/c no scientific notation

# %%
# initial reading in of dataset -- large dataset -- takes time to load
# 'parse_dates' parameter - read in dates as datetime objects
# much more time more efficient to read in pickled dataset instead of csv

# all_df = pd.read_csv('data/political_ads.csv', parse_dates=['start_time', 'end_time', 'date_created'])

# %%
# all_df.head(2)

# %%
# saving as a pickle object to retain datetime object

# all_df.to_pickle('data/all_political_ads.pickle')

# %%
# reading in pickled dataset - more time efficient than reading in csv and parsing in dates as datetime objects

all_df = pd.read_pickle('data/all_political_ads.pickle')
all_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %% [markdown]
# ### Initial Exploration of Data

# %%
all_df.shape
# Out:
# (364718, 19)

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364718 entries, 0 to 364717
# Data columns (total 19 columns):
# id               364718 non-null int64
# wp_identifier    364718 non-null int64
# network          364718 non-null object
# location         364693 non-null object
# program          364704 non-null object
# program_type     364718 non-null object
# start_time       364718 non-null datetime64[ns]
# end_time         364718 non-null datetime64[ns]
# archive_id       364718 non-null object
# embed_url        364718 non-null object
# sponsors         363556 non-null object
# sponsor_types    363556 non-null object
# race             334846 non-null object
# cycle            335617 non-null float64
# subjects         343932 non-null object
# candidates       339591 non-null object
# type             364718 non-null object
# message          364718 non-null object
# date_created     364718 non-null datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), int64(2), object(13)
# memory usage: 52.9+ MB

# %%
all_df.describe()
# Out:
#               id  wp_identifier      cycle
# count 364,718.00     364,718.00 335,617.00
# mean  237,070.53       4,078.86   2,016.00
# std   139,393.65       2,709.65       0.00
# min         1.00         232.00   2,016.00
# 25%   114,419.25       1,213.00   2,016.00
# 50%   222,862.50       4,685.00   2,016.00
# 75%   372,456.75       6,714.00   2,016.00
# max   464,741.00       8,404.00   2,016.00

# %%
all_df.columns
# Out:
# Index(['id', 'wp_identifier', 'network', 'location', 'program', 'program_type',
#        'start_time', 'end_time', 'archive_id', 'embed_url', 'sponsors',
#        'sponsor_types', 'race', 'cycle', 'subjects', 'candidates', 'type',
#        'message', 'date_created'],
#       dtype='object')

# %%
# number of unique items per feature

for column in all_df.columns:
    print ("{:<20s} {:>6.0f}".format(column, all_df[column].nunique()))
    
# review how to print to get the numbers lined up nicely-- see Course-Syllabus 9.6
# Out:
# id                   364718
# wp_identifier          1304
# network                 130
# location                 25
# program                3124
# program_type              2
# start_time           352660
# end_time             352938
# archive_id             1304
# embed_url              1304
# sponsors                197
# sponsor_types            11
# race                     28
# cycle                     1
# subjects                916
# candidates              149
# type                      2
# message                   5
# date_created          17705

# %% [markdown]
# **- from unique values, looks like database has ads for all races not just the presidential race**

# %%
unique_categories = ['network',
                     'location',
                     'program_type',
                     'sponsor_types',
                     'race',
                     'candidates',
                     'type',
                     'message'
                    ]

# %%
# seeing what the unique categories are within each column

for category in unique_categories:
    print (category, '\n')
    print (all_df[category].unique())
    print ('\n')
# Out:
# network
#
# ['KLAS' 'WNCN' 'WFLA' 'KSNV' 'WTVT' 'WTOG' 'WLFL' 'WOIO' 'WRAL' 'WEWS'
#  'WRAZ' 'KVVU' 'KCRG' 'WFTS' 'KFXA' 'KGAN' 'KTNV' 'WTXF' 'WJW' 'WKYC'
#  'WCAU' 'KYW' 'WPVI' 'KUSA' 'WTMJ' 'KNTV' 'KOFY' 'CNNW' 'MSNBCW' 'KPNX'
#  'WHDH' 'FOXNEWSW' 'CSPAN' 'WMUR' 'WBZ' 'WFXT' 'WCVB' 'KQED' 'FBC' 'KMTP'
#  'KRON' 'KTVU' 'KSAZ' 'WISN' 'KGO' 'KNXV' 'KPHO' 'LINKTV' 'WITI' 'WDJT'
#  'CNBC' 'KMGH' 'KCNC' 'WUSA' 'KDVR' 'WTTG' 'CSPAN2' 'CSPAN3' 'WJLA'
#  'BLOOMBERG' 'KCSM' 'KPIX' 'WKMG' 'ALJAZAM' 'KCAU' 'COM' 'WABC' 'KDTV'
#  'WNYW' 'KSTS' 'WRC' 'KTSF' 'WNBC' 'KOLO' 'WUVP' 'WCBS' 'KMEG' 'KTVN'
#  'WKRC' 'WHO' 'KRNV' 'WVEC' 'WOI' 'WSPA' 'WXIX' 'WCPO' 'WLWT' 'WAVY' 'WVBT'
#  'WTKR' 'WHNS' 'WYFF' 'KTIV' 'KWWL' 'KCCI' 'WLOS' 'KRXI' 'KDSM' 'KPTH'
#  'KRDO' 'WPLG' 'WCNC' 'WTVJ' 'FRANCE24' 'WSVN' 'WBTV' 'WTSP' 'WIS' 'WFTV'
#  'WLTX' 'WTVD' 'WOLO' 'WSET' 'WOFL' 'WSOC' 'WFOR' 'WSLS' 'WACH' 'WESH'
#  'WJZY' 'WDBJ' 'WFXR' 'KKTV' 'KOAA' 'KXRM' 'KQEH' 'BBCAMERICA' 'KCNS'
#  'BETW' 'BBCNEWS']
#
#
# location
#
# ['Las Vegas, NV' 'Raleigh-Durham-Fayetteville,  NC'
#  'Tampa-St. Petersburg, FL' 'Cleveland, Ohio'
#  'Ceder Rapids-Waterloo-Iowa City-Dublin, Iowa' 'Philadelphia, PA'
#  'Denver, CO' 'Milwaukee, WI' 'San Francisco-Oakland-San Jose, CA'
#  'Phoenix-Prescott, AZ' 'Boston, MA/Manchester, NH'
#  'Washington, DC/Hagerstown, MD' 'Orlando-Daytona Beach-Melbourne, FL'
#  'Sioux City, Iowa' 'New York City, NY' 'Reno, NV' 'Cincinnati, OH'
#  'Des Moines-Ames, Iowa' 'Norfolk-Portsmouth-Newport News, NC'
#  'Greenville-Spartanburg, SC/Asheville-Anderson, NC'
#  'Colorado Springs-Pueblo, CO' 'Miami-Fort Lauderdale, FL' 'Charlotte, NC'
#  'Columbia, SC' 'Roanoke-Lynchburg, VA' nan]
#
#
# program_type
#
# ['news' 'not news']
#
#
# sponsor_types
#
# ['Multiple' 'Hybrid Super PAC' 'Super PAC' 'Candidate Committee' 'PAC'
#  'Unknown' 'Non Profit' 'Trade Association' nan
#  'Joint Fundraising Committee' 'Corporation' '527']
#
#
# race
#
# ['PRES' 'NHS1' 'PAS1' 'AZS1' 'AZ05' 'WIS2' nan 'INS2' 'WI01' 'ILS2' 'CAS1'
#  'MD08' 'PA08' 'MDS2' 'MD04' 'PA02' 'KS01' 'IAS1' 'NCS2' 'NVS2' 'OHS2'
#  'COS1' 'FLS2' 'CO06' 'OH08' 'OH14' 'NC02' 'NC11' 'NJ03']
#
#
# candidates
#
# ['Hillary Clinton' 'Donald Trump' 'Marco Rubio' 'Kelly Ayotte'
#  'Kelly Ayotte, Maggie Hassan' 'Donald Trump, Hillary Clinton' 'Pat Toomey'
#  'Maggie Hassan' 'Ann Kirkpatrick' 'Andy Biggs, Don Stapley, Don Stapley'
#  'Katie McGinty, Pat Toomey' 'Marco Rubio, Patrick Murphy' 'Russ Feingold'
#  'Ron Johnson, Russ Feingold' nan 'Katie McGinty' 'Christine Jones'
#  'Ann Kirkpatrick, Hillary Clinton, John McCain'
#  'Donald Trump, Gary Johnson, Gary Johnson' 'Michael Bennet'
#  'Donald Trump, John McCain, Kelly Ayotte, Marco Rubio, Richard Burr, Rob Portman, Ron Johnson, Roy Blunt'
#  'Ron Johnson' 'Donald Trump, Gary Johnson, Gary Johnson, Hillary Clinton'
#  'Donald Trump, Rob Portman, Ted Strickland' 'Todd Young'
#  'John McCain, Kelli Ward' 'Donald Trump, Marco Rubio'
#  'Donald Trump, Kelly Ayotte' 'Gary Johnson, Gary Johnson'
#  'Bernie Sanders, Hillary Clinton'
#  'Alan Grayson, Hillary Clinton, Marco Rubio, Pat Murphy'
#  'Donald Trump, John McCain' 'Paul Nehlen, Paul Ryan'
#  'Ann Kirkpatrick, John McCain' 'Paul Ryan' 'Donald Trump, Mark Kirk'
#  'Donald Trump, Pat Toomey' 'John Fetterman' 'Bernie Sanders'
#  'Loretta Sanchez' 'Kamala D Harris' 'Donald Trump, Ted Cruz' 'Ted Cruz'
#  'John Kasich' 'Jamie Raskin' 'Steve Santarsiero' 'Kathleen Matthews'
#  'Joe Sestak, Katie McGinty' 'Shaughnessy Naughton, Steve Santarsiero'
#  'Donna Edwards' 'David Trone, Jamie Raskin, Kathleen Matthews'
#  'Chris Van Hollen' 'David Trone' 'Glenn Ivey' 'Joe Sestak'
#  'Chris Van Hollen, Donna Edwards'
#  'Ann Kirkpatrick, Donald Trump, John McCain'
#  'Donald Trump, John Kasich, Ted Cruz'
#  'Donald Trump, Katie McGinty, Pat Toomey' 'Kumar Barve' 'Anthony Brown'
#  'Joseline Pena-Melnyk'
#  'Ben Carson, Hillary Clinton, John Kasich, Ted Cruz' 'Dwight Evans'
#  'Shaughnessy Naughton'
#  'Donald Trump, Hillary Clinton, John Kasich, Ted Cruz'
#  'Joe Sestak, Pat Toomey' 'Donald Trump, John Kasich'
#  'Hillary Clinton, Marco Rubio' 'Donald Trump, Marco Rubio, Ted Cruz'
#  'Bernie Sanders, Hillary Clinton, Marco Rubio, Ted Cruz'
#  'Hillary Clinton, John Kasich, Marco Rubio' 'Willie Wilson'
#  'Jeb Bush, John Kasich'
#  'Ben Carson, Donald Trump, Jeb Bush, Marco Rubio, Ted Cruz'
#  'Donald Trump, Jeb Bush, Marco Rubio' 'Carly Fiorina' 'Jeb Bush'
#  'Marco Rubio, Ted Cruz' 'Donald Trump, Jeb Bush, Ted Cruz'
#  'Bernie Sanders, Ted Cruz' 'Tim Huelskamp' 'Jeb Bush, Marco Rubio'
#  'Chris Christie, Marco Rubio' 'Jeb Bush, John Kasich, Marco Rubio'
#  'Donald Trump, Jeb Bush' 'Rand Paul, Ted Cruz'
#  'Bernie Sanders, Donald Trump, Hillary Clinton' 'Jim Gilmore'
#  'Mike Huckabee' 'Chris Christie' 'Donald Trump, Mike Huckabee' 'Rand Paul'
#  'Donald Trump, Hillary Clinton, Jeb Bush, Marco Rubio, Ted Cruz, Carson'
#  'Donald Trump, Hillary Clinton, Jeb Bush' 'Ben Carson'
#  'Jeb Bush, Marco Rubio, Ted Cruz' 'Chris Christie, John Kasich' 'Kasich'
#  'Mike Huckabee, Ted Cruz' 'Hillary Clinton, Jeb Bush, Marco Rubio'
#  'Chris Christie, Hillary Clinton'
#  'Chris Christie, Donald Trump, Hillary Clinton, Jeb Bush, Ted Cruz'
#  'Chris Christie, Jeb Bush, John Kasich'
#  'Donald Trump, Jeb Bush, Marco Rubio, Ted Cruz'
#  'Chris Christie, Donald Trump, Hillary Clinton, John Kasich, Marco Rubio'
#  'none' 'Ann Kirkpatrick, Hillary Clinton' 'Jill Stein'
#  'Hillary Clinton, Russ Feingold' 'Hillary Clinton, Tim Kaine'
#  'Donald Trump, Mark Kirk, Tammy Duckworth' 'John McCain' 'Chuck Grassley'
#  'Deborah Ross' 'Joe Heck' 'Catherine Cortez Masto' 'Richard Burr'
#  'Rob Portman' 'Ted Strickland' 'Deborah Ross, Richard Burr'
#  'Patrick Murphy' 'Chuck Grassley, Patty Judge' 'Donald Trump, Joe Heck'
#  'Catherine Cortez Masto, Joe Heck' 'Patty Judge'
#  'Rob Portman, Ted Strickland'
#  'Donald Trump, Hillary Clinton, Mike Coffman' 'Michael F Bennet'
#  'Warren Davidson' 'P G Sittenfeld' 'Hillary Clinton, Warren Davidson'
#  'P G Sittenfeld, Ted Strickland' 'David P Joyce, Matt Lynch'
#  'Bill Beagle, Tim Derickson, Warren Davidson' 'Renee Ellmers'
#  'Mark R Meadows' 'Pat McCrory' 'Roy Cooper'
#  'Donald Trump, Ron Johnson, Russ Feingold'
#  'Donald Trump, Marco Rubio, Patrick Murphy' 'Donald Trump, Richard Burr'
#  'Evan Bayh' 'Darryl Glenn, Michael Bennet' 'Darryl Glenn'
#  'Gerald Daugherty'
#  'Donald Trump, Gary Johnson, Gary Johnson, Hillary Clinton, Jill Stein'
#  'Frederick Lavergne'
#  'Catherine Cortez Masto, Hillary Clinton, Katie McGinty, Patrick Murphy, Ted Strickland'
#  'Brian Fitzpatrick, Donald Trump']
#
#
# type
#
# ['campaign' 'issue']
#
#
# message
#
# ['pro' 'con' 'mixed' 'unknown' 'mix']

# %% [markdown]
# ### Coding Plan I
#
# - limit ads only to presidential race
# - focus on general election -- limit dates from after the conventions (8/1/16) to Election Day (11/8/16)

# %%
# using a copy to be safe

filter_df = all_df.copy()
filter_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %%
# filtering out all all dates before 8/1/2016

filter_df = filter_df[filter_df['start_time'] >= datetime(2016, 8, 1, 0, 0)]
filter_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %%
filter_df.shape
# Out:
# (201445, 19)

# %%
# excluding the dates before 8/1/16 reduced the number of observations by 163,273 or ~45%

filter_df.shape[0] - all_df.shape[0], ((filter_df.shape[0] - all_df.shape[0]) / all_df.shape[0]) * 100
# Out:
# (-163273, -44.76691580892635)

# %%
# odd that they had ads after election day (runoff elections e.g., Louisiana) -- will filter out post 11/8/16

filter_df['start_time'].min(), filter_df['start_time'].max()
# Out:
# (Timestamp('2016-08-01 00:35:22'), Timestamp('2016-11-29 18:44:37'))

# %%
filter_df = filter_df[filter_df['start_time'] <= datetime(2016, 11, 8, 23, 59, 59)]
filter_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %%
# excluding ads after 11/8/16 - removed another 162

filter_df.shape
# Out:
# (201283, 19)

# %%
# now use boolean selection to limit observations to presidential race only

filter_df = filter_df[filter_df['race'] == 'PRES']
filter_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %%
# confirming that mask worked

filter_df['race'].unique()
# Out:
# array(['PRES'], dtype=object)

# %%
filter_df.shape
# Out:
# (85152, 19)

# %%
# removed another 116,131 observations by limiting to the presidential race

201283 - 85152
# Out:
# 116131

# %% [markdown]
# ### Coding Plan II - Initial Feature Engineering
#
# - create `raw_pres_df` and pickle from `filter_df.copy()`
# - new features: `ad_length`, `time_from_creation` (in days)
# - split `location` to create separate `metro_area` and `state` features
# - `day_of_week` feature created from `start_time` columns
# - `subject_count` feature -- number of subjects mentioned per ad -- derived from `subjects` column
# - note potential gotcha on timestamps -- do times reflect local time of recording, UTC or time zone of computer

# %%
raw_pres_df = filter_df.copy()

# %%
# raw_pres_df.to_pickle('data/pres_raw_data.pickle')

# %%
pres_df = raw_pres_df.copy()

# %%
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created
# 0  campaign     pro 2016-09-12 14:49:32
# 1  campaign     pro 2016-09-12 14:49:32

# %% [markdown]
# ### Creating `ad_length` feature

# %%
pres_df['ad_length_tmp'] = pres_df['end_time'] - pres_df['start_time']
pres_df['ad_length_tmp'].head(10)
# Out:
# 0   00:00:30
# 1   00:00:30
# 2   00:00:30
# 3   00:00:30
# 4   00:00:30
# 5   00:00:30
# 6   00:00:30
# 7   00:00:30
# 8   00:00:30
# 9   00:00:30
# Name: ad_length_tmp, dtype: timedelta64[ns]

# %%
# converting to seconds for readability

pres_df['ad_length_tmp'] = pres_df['ad_length_tmp'] / np.timedelta64(1, 's')
pres_df['ad_length_tmp'].head(10)
# Out:
# 0   30.00
# 1   30.00
# 2   30.00
# 3   30.00
# 4   30.00
# 5   30.00
# 6   30.00
# 7   30.00
# 8   30.00
# 9   30.00
# Name: ad_length_tmp, dtype: float64

# %%
# satisfied with conversion - make tmp column permanent - just practicing drop -- could have just renamed column

pres_df['ad_length'] = pres_df['ad_length_tmp']

# %%
pres_df.drop('ad_length_tmp', inplace=True, axis=1)
pres_df.head()
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
# 2   3           5643    KLAS                     Las Vegas, NV
# 3   4           5643    WFLA          Tampa-St. Petersburg, FL
# 4   5           5643    KSNV                     Las Vegas, NV
#
#                                   program program_type          start_time  \
# 0                      8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1            North Carolina News at 500PM         news 2016-09-06 21:58:25
# 2                         Face the Nation         news 2016-09-04 16:24:25
# 3                       Days of Our Lives     not news 2016-08-30 17:59:20
# 4  The Tonight Show Starring Jimmy Fallon         news 2016-09-06 07:02:22
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
# 2 2016-09-04 16:24:55  PolAd_HillaryClinton_f1h3j
# 3 2016-08-30 17:59:50  PolAd_HillaryClinton_f1h3j
# 4 2016-09-06 07:02:52  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 2  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 3  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 4  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 2      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 3      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 4      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length
# 0  campaign     pro 2016-09-12 14:49:32      30.00
# 1  campaign     pro 2016-09-12 14:49:32      30.00
# 2  campaign     pro 2016-09-12 14:49:32      30.00
# 3  campaign     pro 2016-09-12 14:49:32      30.00
# 4  campaign     pro 2016-09-12 14:49:32      30.00

# %%
pres_df['ad_length'].describe()
# Out:
# count   85,152.00
# mean        33.19
# std         11.20
# min         15.00
# 25%         30.00
# 50%         30.00
# 75%         30.00
# max        184.00
# Name: ad_length, dtype: float64

# %% [markdown]
# ### Creating `time_from_creation` feature (days)

# %%
pres_df['time_from_creation_tmp'] = pres_df['start_time'] - pres_df['date_created']
pres_df['time_from_creation_tmp'].head(10)
# Out:
# 0    -4 days +09:23:27
# 1    -6 days +07:08:53
# 2    -8 days +01:34:53
# 3   -13 days +03:09:48
# 4    -7 days +16:12:50
# 5   -13 days +05:05:42
# 6   -14 days +22:32:58
# 7    -6 days +09:55:28
# 8   -13 days +07:23:27
# 9   -14 days +15:03:29
# Name: time_from_creation_tmp, dtype: timedelta64[ns]

# %%
pres_df['time_from_creation_tmp'].tail(10)
# Out:
# 364039   -21 days +17:33:53
# 364040   -27 days +23:02:53
# 364041   -20 days +00:04:06
# 364042   -27 days +18:48:57
# 364043   -27 days +07:47:33
# 364044   -25 days +17:18:46
# 364045   -21 days +18:32:59
# 364046   -20 days +06:41:44
# 364183   -21 days +05:24:29
# 364184   -21 days +12:40:50
# Name: time_from_creation_tmp, dtype: timedelta64[ns]

# %%
# this feature does not seem to make sense, perhaps 'date_created' is the date the ad record was created -
# not when it was literally created -- therefore going to to drop this created column

pres_df.drop('time_from_creation_tmp', inplace=True, axis=1)
pres_df.head()
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
# 2   3           5643    KLAS                     Las Vegas, NV
# 3   4           5643    WFLA          Tampa-St. Petersburg, FL
# 4   5           5643    KSNV                     Las Vegas, NV
#
#                                   program program_type          start_time  \
# 0                      8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1            North Carolina News at 500PM         news 2016-09-06 21:58:25
# 2                         Face the Nation         news 2016-09-04 16:24:25
# 3                       Days of Our Lives     not news 2016-08-30 17:59:20
# 4  The Tonight Show Starring Jimmy Fallon         news 2016-09-06 07:02:22
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
# 2 2016-09-04 16:24:55  PolAd_HillaryClinton_f1h3j
# 3 2016-08-30 17:59:50  PolAd_HillaryClinton_f1h3j
# 4 2016-09-06 07:02:52  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 2  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 3  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 4  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 2      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 3      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 4      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length
# 0  campaign     pro 2016-09-12 14:49:32      30.00
# 1  campaign     pro 2016-09-12 14:49:32      30.00
# 2  campaign     pro 2016-09-12 14:49:32      30.00
# 3  campaign     pro 2016-09-12 14:49:32      30.00
# 4  campaign     pro 2016-09-12 14:49:32      30.00

# %% [markdown]
# ### Creating `day_of_week` feature - day of the week the ad aired

# %%
pres_df['day_of_week'] = pres_df['start_time'].map(lambda x: x.strftime("%A"))
pres_df.head()
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
# 2   3           5643    KLAS                     Las Vegas, NV
# 3   4           5643    WFLA          Tampa-St. Petersburg, FL
# 4   5           5643    KSNV                     Las Vegas, NV
#
#                                   program program_type          start_time  \
# 0                      8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1            North Carolina News at 500PM         news 2016-09-06 21:58:25
# 2                         Face the Nation         news 2016-09-04 16:24:25
# 3                       Days of Our Lives     not news 2016-08-30 17:59:20
# 4  The Tonight Show Starring Jimmy Fallon         news 2016-09-06 07:02:22
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
# 2 2016-09-04 16:24:55  PolAd_HillaryClinton_f1h3j
# 3 2016-08-30 17:59:50  PolAd_HillaryClinton_f1h3j
# 4 2016-09-06 07:02:52  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 2  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 3  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 4  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 2      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 3      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 4      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 2  campaign     pro 2016-09-12 14:49:32      30.00      Sunday
# 3  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 4  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday

# %% [markdown]
# ### Creating `metro_area` and `state` features
#
# - need to split strings in `location` and then access separately via list slicing

# %%
# testing proof of concept -- going to split 'location' and then access separately

pres_df['location'][0].split(',')
# Out:
# ['Las Vegas', ' NV']

# %%
# checking for NaNs in `location`

# going to have an issue because there are NaN's -- cannot split NaN's -- going to get an error

pres_df['location'].unique()
# Out:
# array(['Las Vegas, NV', 'Raleigh-Durham-Fayetteville,  NC',
#        'Tampa-St. Petersburg, FL', 'Cleveland, Ohio',
#        'Ceder Rapids-Waterloo-Iowa City-Dublin, Iowa', 'Philadelphia, PA',
#        'Denver, CO', 'Milwaukee, WI', 'San Francisco-Oakland-San Jose, CA',
#        'Phoenix-Prescott, AZ', 'Boston, MA/Manchester, NH',
#        'Washington, DC/Hagerstown, MD', 'New York City, NY', nan], dtype=object)

# %%
# How many NaN's -- pretty good case to drop observations with location NaN's as only 25 out of 85K observations

pres_df['location'].isnull().sum(), pres_df.shape
# Out:
# (25, (85152, 21))

# %%
# dropping rows where 'location' NaNs

pres_df.dropna(subset=['location'], inplace=True)
pres_df.shape
# Out:
# (85127, 21)

# %%
# confirming removal of NaNs in 'location'

pres_df['location'].unique()
# Out:
# array(['Las Vegas, NV', 'Raleigh-Durham-Fayetteville,  NC',
#        'Tampa-St. Petersburg, FL', 'Cleveland, Ohio',
#        'Ceder Rapids-Waterloo-Iowa City-Dublin, Iowa', 'Philadelphia, PA',
#        'Denver, CO', 'Milwaukee, WI', 'San Francisco-Oakland-San Jose, CA',
#        'Phoenix-Prescott, AZ', 'Boston, MA/Manchester, NH',
#        'Washington, DC/Hagerstown, MD', 'New York City, NY'], dtype=object)

# %% [markdown]
# ### Now creating `split_location_tmp`

# %%
pres_df['split_location_tmp'] = pres_df['location'].map(lambda x: x.split(','))
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     split_location_tmp
# 0                     [Las Vegas,  NV]
# 1  [Raleigh-Durham-Fayetteville,   NC]

# %%
pres_df['split_location_tmp'].head()
# Out:
# 0                       [Las Vegas,  NV]
# 1    [Raleigh-Durham-Fayetteville,   NC]
# 2                       [Las Vegas,  NV]
# 3            [Tampa-St. Petersburg,  FL]
# 4                       [Las Vegas,  NV]
# Name: split_location_tmp, dtype: object

# %% [markdown]
# ### Use `split_location_tmp` to create `metro_area`

# %%
pres_df['metro_area'] = pres_df['split_location_tmp'].map(lambda x: x[0])
pres_df['metro_area'].head()
# Out:
# 0                      Las Vegas
# 1    Raleigh-Durham-Fayetteville
# 2                      Las Vegas
# 3           Tampa-St. Petersburg
# 4                      Las Vegas
# Name: metro_area, dtype: object

# %%
pres_df['metro_area'].tail()
# Out:
# 364042    Cleveland
# 364043    Cleveland
# 364044    Cleveland
# 364045    Cleveland
# 364046    Cleveland
# Name: metro_area, dtype: object

# %%
pres_df['metro_area'].unique()
# Out:
# array(['Las Vegas', 'Raleigh-Durham-Fayetteville', 'Tampa-St. Petersburg',
#        'Cleveland', 'Ceder Rapids-Waterloo-Iowa City-Dublin',
#        'Philadelphia', 'Denver', 'Milwaukee',
#        'San Francisco-Oakland-San Jose', 'Phoenix-Prescott', 'Boston',
#        'Washington', 'New York City'], dtype=object)

# %%
pres_df['metro_area'].value_counts()
# Out:
# Tampa-St. Petersburg                      13248
# Philadelphia                              11949
# Las Vegas                                 10953
# Cleveland                                 10604
# San Francisco-Oakland-San Jose             7546
# Raleigh-Durham-Fayetteville                6731
# Ceder Rapids-Waterloo-Iowa City-Dublin     5295
# Boston                                     5008
# Denver                                     4710
# Milwaukee                                  4097
# Phoenix-Prescott                           3244
# Washington                                 1695
# New York City                                47
# Name: metro_area, dtype: int64

# %% [markdown]
# ### Using the same methodology, creating `state` feature

# %%
pres_df['state'] = pres_df['split_location_tmp'].map(lambda x: x[1])
pres_df['state'].head()
# Out:
# 0      NV
# 1      NC
# 2      NV
# 3      FL
# 4      NV
# Name: state, dtype: object

# %%
pres_df['state'].unique()
# Out:
# array([' NV', '  NC', ' FL', ' Ohio', ' Iowa', ' PA', ' CO', ' WI', ' CA',
#        ' AZ', ' MA/Manchester', ' DC/Hagerstown', ' NY'], dtype=object)

# %% [markdown]
# ### Notes:
#
# - a little cleanup may be required here using some domain knowledge
#
# - Boston media market most likely used to target New Hampshire voters -- convert "MA/Manchester" to New Hampshire
#
# - DC/Hagerstown media buys used to influence Virgina state race
#
# - could ignore and go with current labels (as we know what they are), but going to change
#
# - while at it, could change CA to "National" as they were network buys (San Francisco Market)
#
# - a little uncertainty over why they were NY observations -- could ads shown in NYC stations be targeted at eastern PA??
#
# - there is a case for dropping the NY observations as they are only 47 out of 85K - did end up dropping NY observations in another notebook -- used non-NY dataset to generate visualizations

# %%
# using `.str.replace(A, B)` to get all states in same 2 letter abbreviation format

pres_df['state'] = pres_df['state'].str.replace(' MA/Manchester', 'NH')
pres_df['state'] = pres_df['state'].str.replace(' DC/Hagerstown', 'VA')
pres_df['state'] = pres_df['state'].str.replace(' Ohio', 'OH')
pres_df['state'] = pres_df['state'].str.replace(' Iowa', 'IA')
pres_df['state'] = pres_df['state'].str.replace(' CA', 'National')

# %%
# getting rid of unnecessary whitespace in the labels - could be a gotcha later on

pres_df['state'] = pres_df['state'].map(lambda x: x.strip())

# %%
pres_df['state'].value_counts()
# Out:
# FL          13248
# PA          11949
# NV          10953
# OH          10604
# National     7546
# NC           6731
# IA           5295
# NH           5008
# CO           4710
# WI           4097
# AZ           3244
# VA           1695
# NY             47
# Name: state, dtype: int64

# %%
# doing some housekeepin on the DataFrame by dropping the 'split_location_tmp' column

pres_df.drop('split_location_tmp', inplace=True, axis=1)
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state
# 0                    Las Vegas    NV
# 1  Raleigh-Durham-Fayetteville    NC

# %%
pres_df.shape
# Out:
# (85127, 23)

# %% [markdown]
# ### Creating `subject_count` feature
#
# - use same basic methodology as in creation of `metro_area` and `state` features from splitting `location`

# %%
# proof of concept

len(pres_df['subjects'][0].split())
# Out:
# 3

# %%
# checking for NaNs

pres_df['subjects'].isnull().sum()
# Out:
# 591

# %%
pres_df.ix[362865] # how to get row info by index number
# Out:
# id                                                          462751
# wp_identifier                                                 8248
# network                                                       WUVP
# location                                          Philadelphia, PA
# program                                          Despierta America
# program_type                                                  news
# start_time                                     2016-10-19 12:33:03
# end_time                                       2016-10-19 12:34:18
# archive_id                              PolAd_HillaryClinton_ia316
# embed_url        https://archive.org/embed/PolAd_HillaryClinton...
# sponsors                                        America Rising PAC
# sponsor_types                                            Super PAC
# race                                                          PRES
# cycle                                                     2,016.00
# subjects                                                       NaN
# candidates                                         Hillary Clinton
# type                                                      campaign
# message                                                        con
# date_created                                   2016-11-17 07:40:05
# ad_length                                                    75.00
# day_of_week                                              Wednesday
# metro_area                                            Philadelphia
# state                                                           PA
# Name: 362865, dtype: object

# %%
pres_df.ix[362865]['subjects'] # how to get row info by index number and column
# Out:
# nan

# %%
pres_df['subjects'].nunique() # unique combinations of ad topics
# Out:
# 212

# %%
pres_df['subjects'].describe()
# Out:
# count                                    84536
# unique                                     212
# top       Women, Candidate Biography, Children
# freq                                      4184
# Name: subjects, dtype: object

# %%
# writing a function to split the cell, but keep NaNs - use apply + function to transform column

def subject_count(cell):
    try:
        s_count = len((cell).split(','))
    except AttributeError:
        return np.nan
    return s_count

# could have used this pattern from asynch

#if cell is np.nan:
        #return np.nan -- if it's NaN, leave it
    
# there is a gotcha that np.nan == np.nan returns FALSE, but if you use 'np.nan is np.nan' get TRUE, 
# or use try and except as we di here

# %%
# applying subject_count function to `subject_count_tmp`

pres_df['subject_count_tmp'] = pres_df['subjects'].apply(subject_count) # can use apply instead of map
pres_df.head()
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
# 2   3           5643    KLAS                     Las Vegas, NV
# 3   4           5643    WFLA          Tampa-St. Petersburg, FL
# 4   5           5643    KSNV                     Las Vegas, NV
#
#                                   program program_type          start_time  \
# 0                      8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1            North Carolina News at 500PM         news 2016-09-06 21:58:25
# 2                         Face the Nation         news 2016-09-04 16:24:25
# 3                       Days of Our Lives     not news 2016-08-30 17:59:20
# 4  The Tonight Show Starring Jimmy Fallon         news 2016-09-06 07:02:22
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
# 2 2016-09-04 16:24:55  PolAd_HillaryClinton_f1h3j
# 3 2016-08-30 17:59:50  PolAd_HillaryClinton_f1h3j
# 4 2016-09-06 07:02:52  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 2  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 3  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 4  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 2      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 3      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 4      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 2  campaign     pro 2016-09-12 14:49:32      30.00      Sunday
# 3  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 4  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count_tmp
# 0                    Las Vegas    NV               3.00
# 1  Raleigh-Durham-Fayetteville    NC               3.00
# 2                    Las Vegas    NV               3.00
# 3         Tampa-St. Petersburg    FL               3.00
# 4                    Las Vegas    NV               3.00

# %%
pres_df['subject_count_tmp'].value_counts(dropna=False)

# this is a gotcha - have to put dropna=False in order to get the NaN's in value_counts
# want to keep the NaN's b/c can do math on the series (if convert NaNs to strings cannot do so)
# Out:
# 3.00    20787
# 4.00    19869
# 2.00    15428
# 5.00    11875
# 6.00     5942
# 1.00     4716
# 7.00     3827
# 8.00     2092
# nan       591
# Name: subject_count_tmp, dtype: int64

# %%
type(pres_df['subject_count_tmp'][0])
# Out:
# numpy.float64

# %%
pres_df['subject_count_tmp'].mean(), pres_df['subject_count_tmp'].median()
# Out:
# (3.7375910854547176, 4.0)

# %%
pres_df.shape
# Out:
# (85127, 24)

# %%
# since happy with subject_count - rename the column - get rid of the tmp tag

pres_df = pres_df.rename(columns={'subject_count_tmp': 'subject_count'})
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count
# 0                    Las Vegas    NV           3.00
# 1  Raleigh-Durham-Fayetteville    NC           3.00

# %%
# can also rename columns inplace

pres_df.rename(columns={'subject_count': 'subject_count_test'}, inplace=True)
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count_test
# 0                    Las Vegas    NV                3.00
# 1  Raleigh-Durham-Fayetteville    NC                3.00

# %%
# changing back to `subject_count`

pres_df.rename(columns={'subject_count_test': 'subject_count'}, inplace=True)
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count
# 0                    Las Vegas    NV           3.00
# 1  Raleigh-Durham-Fayetteville    NC           3.00

# %% [markdown]
# ### Pickling `pres_df` to preserve this intemediate stage of the EDA/Cleaning/Feature Engineering Process
#
# - old notebook `Political_Ads_EDA_v3` ended here by pickling `pres_df` at this stage of the process
# - `Political_Ads_Visualizations_v3` continued the EDA/Cleaning/Feature Engineering process by reading in the pickled data filename below

# %%
# comment over to prevent overwrite

# pres_df.to_pickle('data/pres_sorted_data.pickle')

# %% [markdown]
# ### Creating `hour_aired` - hour of the day (military time) that ad aired

# %%
pres_df['hour_aired'] = pres_df['start_time'].map(lambda x: int(x.strftime("%H")))
pres_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count  hour_aired
# 0                    Las Vegas    NV           3.00           0
# 1  Raleigh-Durham-Fayetteville    NC           3.00          21

# %%
pres_df['hour_aired'].dtypes
# Out:
# dtype('int64')

# %%
pres_df['hour_aired'].value_counts()
# Out:
# 23    6836
# 22    6311
# 12    5163
# 21    5098
# 13    4848
# 3     4663
# 11    4095
# 16    3976
# 10    3848
# 4     3753
# 14    3702
# 2     3483
# 20    3241
# 15    3213
# 0     3134
# 9     2897
# 19    2738
# 1     2702
# 5     2631
# 17    2405
# 18    2191
# 6     1709
# 8     1540
# 7      950
# Name: hour_aired, dtype: int64

# %%
len(pres_df['hour_aired'].value_counts()) # sanity check - should be 24
# Out:
# 24

# %%
pres_df.head()
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
# 2   3           5643    KLAS                     Las Vegas, NV
# 3   4           5643    WFLA          Tampa-St. Petersburg, FL
# 4   5           5643    KSNV                     Las Vegas, NV
#
#                                   program program_type          start_time  \
# 0                      8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1            North Carolina News at 500PM         news 2016-09-06 21:58:25
# 2                         Face the Nation         news 2016-09-04 16:24:25
# 3                       Days of Our Lives     not news 2016-08-30 17:59:20
# 4  The Tonight Show Starring Jimmy Fallon         news 2016-09-06 07:02:22
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
# 2 2016-09-04 16:24:55  PolAd_HillaryClinton_f1h3j
# 3 2016-08-30 17:59:50  PolAd_HillaryClinton_f1h3j
# 4 2016-09-06 07:02:52  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 2  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 3  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 4  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 2      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 3      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 4      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 2  campaign     pro 2016-09-12 14:49:32      30.00      Sunday
# 3  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
# 4  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count  hour_aired
# 0                    Las Vegas    NV           3.00           0
# 1  Raleigh-Durham-Fayetteville    NC           3.00          21
# 2                    Las Vegas    NV           3.00          16
# 3         Tampa-St. Petersburg    FL           3.00          17
# 4                    Las Vegas    NV           3.00           7

# %%
pres_df.shape
# Out:
# (85127, 25)

# %% [markdown]
# ## Setting DataFrame Index to `start_date`

# %%
# Making a copy before setting index to `start_date`

pres_date_df = pres_df.copy()
pres_date_df.head(2)
# Out:
#    id  wp_identifier network                          location  \
# 0   1           5643    KLAS                     Las Vegas, NV
# 1   2           5643    WNCN  Raleigh-Durham-Fayetteville,  NC
#
#                         program program_type          start_time  \
# 0            8 News Now at 5 PM         news 2016-09-09 00:12:59
# 1  North Carolina News at 500PM         news 2016-09-06 21:58:25
#
#              end_time                  archive_id  \
# 0 2016-09-09 00:13:29  PolAd_HillaryClinton_f1h3j
# 1 2016-09-06 21:58:55  PolAd_HillaryClinton_f1h3j
#
#                                            embed_url             sponsors  \
# 0  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
# 1  https://archive.org/embed/PolAd_HillaryClinton...  Hillary for America
#
#   sponsor_types  race    cycle             subjects       candidates  \
# 0      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
# 1      Multiple  PRES 2,016.00  Energy, China, Jobs  Hillary Clinton
#
#        type message        date_created  ad_length day_of_week  \
# 0  campaign     pro 2016-09-12 14:49:32      30.00      Friday
# 1  campaign     pro 2016-09-12 14:49:32      30.00     Tuesday
#
#                     metro_area state  subject_count  hour_aired
# 0                    Las Vegas    NV           3.00           0
# 1  Raleigh-Durham-Fayetteville    NC           3.00          21

# %%
# start_time column was not sorted -- sorting here in ascending order

pres_date_df.sort_values('start_time', ascending=True, inplace=True)
pres_date_df.head(10)
# Out:
#             id  wp_identifier   network                            location  \
# 207673  261456           6035  FOXNEWSW  San Francisco-Oakland-San Jose, CA
# 207667  261450           6035  FOXNEWSW  San Francisco-Oakland-San Jose, CA
# 34380    48222           4176      WCAU                    Philadelphia, PA
# 34553    48395           4176       KYW                    Philadelphia, PA
# 279413  378441           7459    MSNBCW  San Francisco-Oakland-San Jose, CA
# 34552    48394           4176      WCAU                    Philadelphia, PA
# 279420  378448           7459    MSNBCW  San Francisco-Oakland-San Jose, CA
# 207674  261457           6035    MSNBCW  San Francisco-Oakland-San Jose, CA
# 279418  378446           7459    MSNBCW  San Francisco-Oakland-San Jose, CA
# 34551    48393           4176      WTXF                    Philadelphia, PA
#
#                                       program program_type  \
# 207673  On the Record With Greta Van Susteren         news
# 207667     Fox News Sunday With Chris Wallace         news
# 34380               NBC10 News Today at 430am         news
# 34553                  Eyewitness News at 430         news
# 279413                             First Look         news
# 34552                 NBC10 News Today at 5am         news
# 279420                          Way Too Early         news
# 207674                            Morning Joe         news
# 279418                            Morning Joe         news
# 34551             Good Day Philadelphia at 6A         news
#
#                 start_time            end_time                  archive_id  \
# 207673 2016-08-01 01:19:59 2016-08-01 01:21:04  PolAd_HillaryClinton_4drmd
# 207667 2016-08-01 06:20:04 2016-08-01 06:21:09  PolAd_HillaryClinton_4drmd
# 34380  2016-08-01 08:39:49 2016-08-01 08:40:21     PolAd_DonaldTrump_99k4w
# 34553  2016-08-01 08:48:14 2016-08-01 08:48:46     PolAd_DonaldTrump_99k4w
# 279413 2016-08-01 09:09:45 2016-08-01 09:10:15  PolAd_HillaryClinton_4gvic
# 34552  2016-08-01 09:24:05 2016-08-01 09:24:37     PolAd_DonaldTrump_99k4w
# 279420 2016-08-01 09:39:09 2016-08-01 09:39:39  PolAd_HillaryClinton_4gvic
# 207674 2016-08-01 10:26:51 2016-08-01 10:27:56  PolAd_HillaryClinton_4drmd
# 279418 2016-08-01 10:27:50 2016-08-01 10:28:20  PolAd_HillaryClinton_4gvic
# 34551  2016-08-01 10:29:58 2016-08-01 10:30:30     PolAd_DonaldTrump_99k4w
#
#                                                 embed_url  \
# 207673  https://archive.org/embed/PolAd_HillaryClinton...
# 207667  https://archive.org/embed/PolAd_HillaryClinton...
# 34380   https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 34553   https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 279413  https://archive.org/embed/PolAd_HillaryClinton...
# 34552   https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 279420  https://archive.org/embed/PolAd_HillaryClinton...
# 207674  https://archive.org/embed/PolAd_HillaryClinton...
# 279418  https://archive.org/embed/PolAd_HillaryClinton...
# 34551   https://archive.org/embed/PolAd_DonaldTrump_99k4w
#
#                        sponsors sponsor_types  race    cycle  \
# 207673      Reform America Fund     Super PAC  PRES 2,016.00
# 207667      Reform America Fund     Super PAC  PRES 2,016.00
# 34380       Hillary for America      Multiple  PRES 2,016.00
# 34553       Hillary for America      Multiple  PRES 2,016.00
# 279413  Make America Number One     Super PAC  PRES 2,016.00
# 34552       Hillary for America      Multiple  PRES 2,016.00
# 279420  Make America Number One     Super PAC  PRES 2,016.00
# 207674      Reform America Fund     Super PAC  PRES 2,016.00
# 279418  Make America Number One     Super PAC  PRES 2,016.00
# 34551       Hillary for America      Multiple  PRES 2,016.00
#
#                                                  subjects       candidates  \
# 207673                                Candidate Biography  Hillary Clinton
# 207667                                Candidate Biography  Hillary Clinton
# 34380   Candidate Biography, Foreign Policy, Nuclear, ...     Donald Trump
# 34553   Candidate Biography, Foreign Policy, Nuclear, ...     Donald Trump
# 279413                                Candidate Biography  Hillary Clinton
# 34552   Candidate Biography, Foreign Policy, Nuclear, ...     Donald Trump
# 279420                                Candidate Biography  Hillary Clinton
# 207674                                Candidate Biography  Hillary Clinton
# 279418                                Candidate Biography  Hillary Clinton
# 34551   Candidate Biography, Foreign Policy, Nuclear, ...     Donald Trump
#
#             type message        date_created  ad_length day_of_week  \
# 207673  campaign     con 2016-09-21 10:40:12      65.00      Monday
# 207667  campaign     con 2016-09-21 10:40:12      65.00      Monday
# 34380   campaign   mixed 2016-09-12 14:51:51      32.00      Monday
# 34553   campaign   mixed 2016-09-12 14:51:51      32.00      Monday
# 279413  campaign     con 2016-10-21 10:40:01      30.00      Monday
# 34552   campaign   mixed 2016-09-12 14:51:51      32.00      Monday
# 279420  campaign     con 2016-10-21 10:40:01      30.00      Monday
# 207674  campaign     con 2016-09-21 10:40:12      65.00      Monday
# 279418  campaign     con 2016-10-21 10:40:01      30.00      Monday
# 34551   campaign   mixed 2016-09-12 14:51:51      32.00      Monday
#
#                             metro_area     state  subject_count  hour_aired
# 207673  San Francisco-Oakland-San Jose  National           1.00           1
# 207667  San Francisco-Oakland-San Jose  National           1.00           6
# 34380                     Philadelphia        PA           4.00           8
# 34553                     Philadelphia        PA           4.00           8
# 279413  San Francisco-Oakland-San Jose  National           1.00           9
# 34552                     Philadelphia        PA           4.00           9
# 279420  San Francisco-Oakland-San Jose  National           1.00           9
# 207674  San Francisco-Oakland-San Jose  National           1.00          10
# 279418  San Francisco-Oakland-San Jose  National           1.00          10
# 34551                     Philadelphia        PA           4.00          10

# %% [markdown]
# ### Now setting `start_time` as the index for `pres_date_df`

# %%
pres_date_df.set_index('start_time', inplace=True, drop=False) # could have dropped, but in this case kept it
pres_date_df.head(20)
# Out:
#                          id  wp_identifier   network  \
# start_time
# 2016-08-01 01:19:59  261456           6035  FOXNEWSW
# 2016-08-01 06:20:04  261450           6035  FOXNEWSW
# 2016-08-01 08:39:49   48222           4176      WCAU
# 2016-08-01 08:48:14   48395           4176       KYW
# 2016-08-01 09:09:45  378441           7459    MSNBCW
# 2016-08-01 09:24:05   48394           4176      WCAU
# 2016-08-01 09:39:09  378448           7459    MSNBCW
# 2016-08-01 10:26:51  261457           6035    MSNBCW
# 2016-08-01 10:27:50  378446           7459    MSNBCW
# 2016-08-01 10:29:58   48393           4176      WTXF
# 2016-08-01 10:44:40   47489           4508      WCAU
# 2016-08-01 11:22:11   46322           4500      WCAU
# 2016-08-01 11:27:38   47484           4508      CNBC
# 2016-08-01 11:44:53   47482           4508  FOXNEWSW
# 2016-08-01 11:57:22   47469           4508       FBC
# 2016-08-01 12:26:02  261458           6035    MSNBCW
# 2016-08-01 12:40:42   47487           4508       KYW
# 2016-08-01 12:44:19   48390           4176      WTXF
# 2016-08-01 12:46:01   48385           4176      WCAU
# 2016-08-01 13:28:54   46323           4500  FOXNEWSW
#
#                                                location  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose, CA
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose, CA
# 2016-08-01 08:39:49                    Philadelphia, PA
# 2016-08-01 08:48:14                    Philadelphia, PA
# 2016-08-01 09:09:45  San Francisco-Oakland-San Jose, CA
# 2016-08-01 09:24:05                    Philadelphia, PA
# 2016-08-01 09:39:09  San Francisco-Oakland-San Jose, CA
# 2016-08-01 10:26:51  San Francisco-Oakland-San Jose, CA
# 2016-08-01 10:27:50  San Francisco-Oakland-San Jose, CA
# 2016-08-01 10:29:58                    Philadelphia, PA
# 2016-08-01 10:44:40                    Philadelphia, PA
# 2016-08-01 11:22:11                    Philadelphia, PA
# 2016-08-01 11:27:38  San Francisco-Oakland-San Jose, CA
# 2016-08-01 11:44:53  San Francisco-Oakland-San Jose, CA
# 2016-08-01 11:57:22  San Francisco-Oakland-San Jose, CA
# 2016-08-01 12:26:02  San Francisco-Oakland-San Jose, CA
# 2016-08-01 12:40:42                    Philadelphia, PA
# 2016-08-01 12:44:19                    Philadelphia, PA
# 2016-08-01 12:46:01                    Philadelphia, PA
# 2016-08-01 13:28:54  San Francisco-Oakland-San Jose, CA
#
#                                                                program  \
# start_time
# 2016-08-01 01:19:59              On the Record With Greta Van Susteren
# 2016-08-01 06:20:04                 Fox News Sunday With Chris Wallace
# 2016-08-01 08:39:49                          NBC10 News Today at 430am
# 2016-08-01 08:48:14                             Eyewitness News at 430
# 2016-08-01 09:09:45                                         First Look
# 2016-08-01 09:24:05                            NBC10 News Today at 5am
# 2016-08-01 09:39:09                                      Way Too Early
# 2016-08-01 10:26:51                                        Morning Joe
# 2016-08-01 10:27:50                                        Morning Joe
# 2016-08-01 10:29:58                        Good Day Philadelphia at 6A
# 2016-08-01 10:44:40                            NBC10 News Today at 6am
# 2016-08-01 11:22:11                                              Today
# 2016-08-01 11:27:38                                         Squawk Box
# 2016-08-01 11:44:53                                        FOX Friends
# 2016-08-01 11:57:22                      Mornings With Maria Bartiromo
# 2016-08-01 12:26:02                                        Morning Joe
# 2016-08-01 12:40:42                                   CBS This Morning
# 2016-08-01 12:44:19                        Good Day Philadelphia at 7A
# 2016-08-01 12:46:01                                              Today
# 2016-08-01 13:28:54  Americas Newsroom With Bill Hemmer and Martha ...
#
#                     program_type          start_time            end_time  \
# start_time
# 2016-08-01 01:19:59         news 2016-08-01 01:19:59 2016-08-01 01:21:04
# 2016-08-01 06:20:04         news 2016-08-01 06:20:04 2016-08-01 06:21:09
# 2016-08-01 08:39:49         news 2016-08-01 08:39:49 2016-08-01 08:40:21
# 2016-08-01 08:48:14         news 2016-08-01 08:48:14 2016-08-01 08:48:46
# 2016-08-01 09:09:45         news 2016-08-01 09:09:45 2016-08-01 09:10:15
# 2016-08-01 09:24:05         news 2016-08-01 09:24:05 2016-08-01 09:24:37
# 2016-08-01 09:39:09         news 2016-08-01 09:39:09 2016-08-01 09:39:39
# 2016-08-01 10:26:51         news 2016-08-01 10:26:51 2016-08-01 10:27:56
# 2016-08-01 10:27:50         news 2016-08-01 10:27:50 2016-08-01 10:28:20
# 2016-08-01 10:29:58         news 2016-08-01 10:29:58 2016-08-01 10:30:30
# 2016-08-01 10:44:40         news 2016-08-01 10:44:40 2016-08-01 10:45:10
# 2016-08-01 11:22:11         news 2016-08-01 11:22:11 2016-08-01 11:23:11
# 2016-08-01 11:27:38         news 2016-08-01 11:27:38 2016-08-01 11:28:08
# 2016-08-01 11:44:53         news 2016-08-01 11:44:53 2016-08-01 11:45:23
# 2016-08-01 11:57:22         news 2016-08-01 11:57:22 2016-08-01 11:57:52
# 2016-08-01 12:26:02         news 2016-08-01 12:26:02 2016-08-01 12:27:07
# 2016-08-01 12:40:42         news 2016-08-01 12:40:42 2016-08-01 12:41:12
# 2016-08-01 12:44:19         news 2016-08-01 12:44:19 2016-08-01 12:44:51
# 2016-08-01 12:46:01         news 2016-08-01 12:46:01 2016-08-01 12:46:33
# 2016-08-01 13:28:54         news 2016-08-01 13:28:54 2016-08-01 13:29:54
#
#                                      archive_id  \
# start_time
# 2016-08-01 01:19:59  PolAd_HillaryClinton_4drmd
# 2016-08-01 06:20:04  PolAd_HillaryClinton_4drmd
# 2016-08-01 08:39:49     PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14     PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  PolAd_HillaryClinton_4gvic
# 2016-08-01 09:24:05     PolAd_DonaldTrump_99k4w
# 2016-08-01 09:39:09  PolAd_HillaryClinton_4gvic
# 2016-08-01 10:26:51  PolAd_HillaryClinton_4drmd
# 2016-08-01 10:27:50  PolAd_HillaryClinton_4gvic
# 2016-08-01 10:29:58     PolAd_DonaldTrump_99k4w
# 2016-08-01 10:44:40  PolAd_HillaryClinton_3762w
# 2016-08-01 11:22:11     PolAd_DonaldTrump_6s4dc
# 2016-08-01 11:27:38  PolAd_HillaryClinton_3762w
# 2016-08-01 11:44:53  PolAd_HillaryClinton_3762w
# 2016-08-01 11:57:22  PolAd_HillaryClinton_3762w
# 2016-08-01 12:26:02  PolAd_HillaryClinton_4drmd
# 2016-08-01 12:40:42  PolAd_HillaryClinton_3762w
# 2016-08-01 12:44:19     PolAd_DonaldTrump_99k4w
# 2016-08-01 12:46:01     PolAd_DonaldTrump_99k4w
# 2016-08-01 13:28:54     PolAd_DonaldTrump_6s4dc
#
#                                                              embed_url  \
# start_time
# 2016-08-01 01:19:59  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 06:20:04  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 08:39:49  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 09:24:05  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 09:39:09  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 10:26:51  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 10:27:50  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 10:29:58  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 10:44:40  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 11:22:11  https://archive.org/embed/PolAd_DonaldTrump_6s4dc
# 2016-08-01 11:27:38  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 11:44:53  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 11:57:22  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 12:26:02  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 12:40:42  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 12:44:19  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 12:46:01  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 13:28:54  https://archive.org/embed/PolAd_DonaldTrump_6s4dc
#
#                                     sponsors sponsor_types  race    cycle  \
# start_time
# 2016-08-01 01:19:59      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 06:20:04      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 08:39:49      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 08:48:14      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 09:09:45  Make America Number One     Super PAC  PRES 2,016.00
# 2016-08-01 09:24:05      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 09:39:09  Make America Number One     Super PAC  PRES 2,016.00
# 2016-08-01 10:26:51      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 10:27:50  Make America Number One     Super PAC  PRES 2,016.00
# 2016-08-01 10:29:58      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 10:44:40   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 11:22:11   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 11:27:38   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 11:44:53   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 11:57:22   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 12:26:02      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 12:40:42   Rebuilding America Now     Super PAC  PRES 2,016.00
# 2016-08-01 12:44:19      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 12:46:01      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 13:28:54   Rebuilding America Now     Super PAC  PRES 2,016.00
#
#                                                               subjects  \
# start_time
# 2016-08-01 01:19:59                                Candidate Biography
# 2016-08-01 06:20:04                                Candidate Biography
# 2016-08-01 08:39:49  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 08:48:14  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 09:09:45                                Candidate Biography
# 2016-08-01 09:24:05  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 09:39:09                                Candidate Biography
# 2016-08-01 10:26:51                                Candidate Biography
# 2016-08-01 10:27:50                                Candidate Biography
# 2016-08-01 10:29:58  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 10:44:40                                        Trade, Jobs
# 2016-08-01 11:22:11                        Jobs, Trade, Infrastructure
# 2016-08-01 11:27:38                                        Trade, Jobs
# 2016-08-01 11:44:53                                        Trade, Jobs
# 2016-08-01 11:57:22                                        Trade, Jobs
# 2016-08-01 12:26:02                                Candidate Biography
# 2016-08-01 12:40:42                                        Trade, Jobs
# 2016-08-01 12:44:19  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 12:46:01  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 13:28:54                        Jobs, Trade, Infrastructure
#
#                           candidates      type message        date_created  \
# start_time
# 2016-08-01 01:19:59  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 06:20:04  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 08:39:49     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 08:48:14     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 09:09:45  Hillary Clinton  campaign     con 2016-10-21 10:40:01
# 2016-08-01 09:24:05     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 09:39:09  Hillary Clinton  campaign     con 2016-10-21 10:40:01
# 2016-08-01 10:26:51  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 10:27:50  Hillary Clinton  campaign     con 2016-10-21 10:40:01
# 2016-08-01 10:29:58     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 10:44:40  Hillary Clinton  campaign     con 2016-09-12 14:51:43
# 2016-08-01 11:22:11     Donald Trump  campaign     pro 2016-09-12 14:51:40
# 2016-08-01 11:27:38  Hillary Clinton  campaign     con 2016-09-12 14:51:43
# 2016-08-01 11:44:53  Hillary Clinton  campaign     con 2016-09-12 14:51:43
# 2016-08-01 11:57:22  Hillary Clinton  campaign     con 2016-09-12 14:51:42
# 2016-08-01 12:26:02  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 12:40:42  Hillary Clinton  campaign     con 2016-09-12 14:51:43
# 2016-08-01 12:44:19     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 12:46:01     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 13:28:54     Donald Trump  campaign     pro 2016-09-12 14:51:40
#
#                      ad_length day_of_week                      metro_area  \
# start_time
# 2016-08-01 01:19:59      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 06:20:04      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 08:39:49      32.00      Monday                    Philadelphia
# 2016-08-01 08:48:14      32.00      Monday                    Philadelphia
# 2016-08-01 09:09:45      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 09:24:05      32.00      Monday                    Philadelphia
# 2016-08-01 09:39:09      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 10:26:51      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 10:27:50      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 10:29:58      32.00      Monday                    Philadelphia
# 2016-08-01 10:44:40      30.00      Monday                    Philadelphia
# 2016-08-01 11:22:11      60.00      Monday                    Philadelphia
# 2016-08-01 11:27:38      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 11:44:53      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 11:57:22      30.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 12:26:02      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 12:40:42      30.00      Monday                    Philadelphia
# 2016-08-01 12:44:19      32.00      Monday                    Philadelphia
# 2016-08-01 12:46:01      32.00      Monday                    Philadelphia
# 2016-08-01 13:28:54      60.00      Monday  San Francisco-Oakland-San Jose
#
#                         state  subject_count  hour_aired
# start_time
# 2016-08-01 01:19:59  National           1.00           1
# 2016-08-01 06:20:04  National           1.00           6
# 2016-08-01 08:39:49        PA           4.00           8
# 2016-08-01 08:48:14        PA           4.00           8
# 2016-08-01 09:09:45  National           1.00           9
# 2016-08-01 09:24:05        PA           4.00           9
# 2016-08-01 09:39:09  National           1.00           9
# 2016-08-01 10:26:51  National           1.00          10
# 2016-08-01 10:27:50  National           1.00          10
# 2016-08-01 10:29:58        PA           4.00          10
# 2016-08-01 10:44:40        PA           2.00          10
# 2016-08-01 11:22:11        PA           3.00          11
# 2016-08-01 11:27:38  National           2.00          11
# 2016-08-01 11:44:53  National           2.00          11
# 2016-08-01 11:57:22  National           2.00          11
# 2016-08-01 12:26:02  National           1.00          12
# 2016-08-01 12:40:42        PA           2.00          12
# 2016-08-01 12:44:19        PA           4.00          12
# 2016-08-01 12:46:01        PA           4.00          12
# 2016-08-01 13:28:54  National           3.00          13

# %% [markdown]
# ## Creating `sponsor_class` feature -- cleaning up and parsing through `sponsors`
#
# - required in order to determine which candidate was responsible for airing the ad and can match candidate to ad message (con, pro, mixed, unknown)
# - had to manually research the 45 unique sponsors in this dataset to determine which candidate they backed
# - primary search tool was OpenSecrets.org and wikipedia.com
# - even though `race` classified ad as for `PRES` - the manual inspection of the `sponsors` showed that there were ads sponsored by senatorial campaigns -- filtered out these observations and sponsors
# - left in 3rd Party candidate observations -- these were easily filtered out in the time series analysis

# %%
pres_date_df['sponsors'].nunique()
# Out:
# 45

# %%
sponsors_list = list(pres_date_df['sponsors'].unique())
sponsors_list
# Out:
# ['Reform America Fund',
#  'Hillary for America',
#  'Make America Number One',
#  'Rebuilding America Now',
#  'NextGen California Action Committee',
#  'Women Vote!',
#  'Reclaim America PAC',
#  'Priorities USA Action',
#  'Donald J Trump For President',
#  'Kirkpatrick For Senate',
#  'Friends of Patrick Murphy',
#  'MoveOn.org',
#  'Our Principles PAC',
#  'Correct The Record',
#  'Marco Rubio For Senate 2016',
#  'Republican National Cmte',
#  'Gary Johnson 2016',
#  'Great America PAC',
#  'Stop Hillary PAC',
#  'National Rifle Assn',
#  'Ready for Hillary',
#  'Democratic Senatorial Campaign Cmte',
#  'Purple PAC',
#  'Jill Stein for President',
#  'Strickland for Senate',
#  'Free the Delegates',
#  'NARAL Pro-Choice America',
#  'American Bridge 21st Century',
#  'Hillary Victory Fund',
#  'Democratic National Cmte',
#  'Fenton Communications Inc',
#  'America Rising PAC',
#  'NextGen Climate Action',
#  'Save the Day PAC',
#  'Future45',
#  'Donald J. Trump For President',
#  'NRA Institute for Legislative Action',
#  'iAmerica Action',
#  'Internet Archive',
#  '45 Committee',
#  'Local Voices',
#  'Fifty Second Street Fund',
#  'National Republican Senatorial Cmte',
#  'American Crossroads',
#  'Victory 2016 Committee']

# %%
pres_date_df['sponsors'].isnull().sum() # gives you the number of NaN's since True = 1
# Out:
# 0

# %% [markdown]
# ### External research on `sponsors`
#
# - Exported sponsors_list a csv file and used MS Excel to annotate with information from OpenSecrets.org and other sources
# - filename is `data/sponsors_list_annotated.csv`

# %%
# code for exporting `sponsors_list` as csv file - easier to work and annotate in excel
# commenting out to prevent overwrite of original version

# import csv

# with open('data/sponsors_list.csv', 'wt') as f:
    # writer = csv.writer(f)
    # for row in sponsors_list:
        # writer.writerow([row])

# %% [markdown]
# ### Reading in Annotated Sponsors List File - `data/sponsors_list_final.csv`
#
# - `Sponsor_Classification` manually determined via web searches

# %%
sponsors_df = pd.read_csv('data/sponsors_list_final.csv', 
                          header=None, 
                          names=['Sponsors', 'Sponsor_Classification'], 
                          index_col='Sponsors')
sponsors_df.head()
# Out:
#                                     Sponsor_Classification
# Sponsors
# Reform America Fund                                  R_PAC
# Hillary for America                                Clinton
# Make America Number One                              R_PAC
# Rebuilding America Now                               R_PAC
# NextGen California Action Committee                  D_PAC

# %%
sponsors_df.values[0:5]
# Out:
# array([['R_PAC'],
#        ['Clinton'],
#        ['R_PAC'],
#        ['R_PAC'],
#        ['D_PAC']], dtype=object)

# %%
# How to access a cell via an index

sponsors_df['Sponsor_Classification']['Reform America Fund']
# Out:
# 'R_PAC'

# %% [markdown]
# ### Creating a mapping dictionary - use to map `Sponsors` to `Sponsor_Classification`

# %%
mapping_dict = {}

for row in sponsors_df.index:
    mapping_dict[row] = sponsors_df['Sponsor_Classification'][row]
    
mapping_dict
# Out:
# {'45 Committee': 'R_PAC',
#  'America Rising PAC': 'R_PAC',
#  'American Bridge 21st Century': 'D_PAC',
#  'American Crossroads': 'R_PAC',
#  'Correct The Record': 'D_PAC',
#  'Democratic National Cmte': 'D_COM',
#  'Democratic Senatorial Campaign Cmte': 'Other',
#  'Donald J Trump For President': 'Trump',
#  'Donald J. Trump For President': 'Trump',
#  'Fenton Communications Inc': 'D_PAC',
#  'Fifty Second Street Fund': 'D_PAC',
#  'Free the Delegates': 'Other',
#  'Friends of Patrick Murphy': 'Other',
#  'Future45': 'R_PAC',
#  'Gary Johnson 2016': 'Johnson',
#  'Great America PAC': 'R_PAC',
#  'Hillary Victory Fund': 'D_PAC',
#  'Hillary for America': 'Clinton',
#  'Internet Archive': 'Other',
#  'Jill Stein for President': 'Stein',
#  'Kirkpatrick For Senate': 'Other',
#  'Local Voices': 'D_PAC',
#  'Make America Number One': 'R_PAC',
#  'Marco Rubio For Senate 2016': 'Other',
#  'MoveOn.org': 'D_PAC',
#  'NARAL Pro-Choice America': 'D_PAC',
#  'NRA Institute for Legislative Action': 'R_PAC',
#  'National Republican Senatorial Cmte': 'Other',
#  'National Rifle Assn': 'R_PAC',
#  'NextGen California Action Committee': 'D_PAC',
#  'NextGen Climate Action': 'D_PAC',
#  'Our Principles PAC': 'D_PAC',
#  'Priorities USA Action': 'D_PAC',
#  'Purple PAC': 'R_PAC',
#  'Ready for Hillary': 'D_PAC',
#  'Rebuilding America Now': 'R_PAC',
#  'Reclaim America PAC': 'Other',
#  'Reform America Fund': 'R_PAC',
#  'Republican National Cmte': 'R_COM',
#  'Save the Day PAC': 'D_PAC',
#  'Stop Hillary PAC': 'R_PAC',
#  'Strickland for Senate': 'Other',
#  'Victory 2016 Committee': 'R_PAC',
#  'Women Vote!': 'D_PAC',
#  'iAmerica Action': 'D_PAC'}

# %% [markdown]
# ### Now use 'mapping_dict' to create a new column that you can sort and mask on
#
# - first make a copy of `pres_date_df` to be safe

# %%
cand_date_df = pres_date_df.copy()
cand_date_df.head()
# Out:
#                          id  wp_identifier   network  \
# start_time
# 2016-08-01 01:19:59  261456           6035  FOXNEWSW
# 2016-08-01 06:20:04  261450           6035  FOXNEWSW
# 2016-08-01 08:39:49   48222           4176      WCAU
# 2016-08-01 08:48:14   48395           4176       KYW
# 2016-08-01 09:09:45  378441           7459    MSNBCW
#
#                                                location  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose, CA
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose, CA
# 2016-08-01 08:39:49                    Philadelphia, PA
# 2016-08-01 08:48:14                    Philadelphia, PA
# 2016-08-01 09:09:45  San Francisco-Oakland-San Jose, CA
#
#                                                    program program_type  \
# start_time
# 2016-08-01 01:19:59  On the Record With Greta Van Susteren         news
# 2016-08-01 06:20:04     Fox News Sunday With Chris Wallace         news
# 2016-08-01 08:39:49              NBC10 News Today at 430am         news
# 2016-08-01 08:48:14                 Eyewitness News at 430         news
# 2016-08-01 09:09:45                             First Look         news
#
#                              start_time            end_time  \
# start_time
# 2016-08-01 01:19:59 2016-08-01 01:19:59 2016-08-01 01:21:04
# 2016-08-01 06:20:04 2016-08-01 06:20:04 2016-08-01 06:21:09
# 2016-08-01 08:39:49 2016-08-01 08:39:49 2016-08-01 08:40:21
# 2016-08-01 08:48:14 2016-08-01 08:48:14 2016-08-01 08:48:46
# 2016-08-01 09:09:45 2016-08-01 09:09:45 2016-08-01 09:10:15
#
#                                      archive_id  \
# start_time
# 2016-08-01 01:19:59  PolAd_HillaryClinton_4drmd
# 2016-08-01 06:20:04  PolAd_HillaryClinton_4drmd
# 2016-08-01 08:39:49     PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14     PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  PolAd_HillaryClinton_4gvic
#
#                                                              embed_url  \
# start_time
# 2016-08-01 01:19:59  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 06:20:04  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 08:39:49  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  https://archive.org/embed/PolAd_HillaryClinton...
#
#                                     sponsors sponsor_types  race    cycle  \
# start_time
# 2016-08-01 01:19:59      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 06:20:04      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 08:39:49      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 08:48:14      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 09:09:45  Make America Number One     Super PAC  PRES 2,016.00
#
#                                                               subjects  \
# start_time
# 2016-08-01 01:19:59                                Candidate Biography
# 2016-08-01 06:20:04                                Candidate Biography
# 2016-08-01 08:39:49  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 08:48:14  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 09:09:45                                Candidate Biography
#
#                           candidates      type message        date_created  \
# start_time
# 2016-08-01 01:19:59  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 06:20:04  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 08:39:49     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 08:48:14     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 09:09:45  Hillary Clinton  campaign     con 2016-10-21 10:40:01
#
#                      ad_length day_of_week                      metro_area  \
# start_time
# 2016-08-01 01:19:59      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 06:20:04      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 08:39:49      32.00      Monday                    Philadelphia
# 2016-08-01 08:48:14      32.00      Monday                    Philadelphia
# 2016-08-01 09:09:45      30.00      Monday  San Francisco-Oakland-San Jose
#
#                         state  subject_count  hour_aired
# start_time
# 2016-08-01 01:19:59  National           1.00           1
# 2016-08-01 06:20:04  National           1.00           6
# 2016-08-01 08:39:49        PA           4.00           8
# 2016-08-01 08:48:14        PA           4.00           8
# 2016-08-01 09:09:45  National           1.00           9

# %% [markdown]
# ### Using `map` and `mapping_dict` to create a new feature `sponsor_class`

# %%
cand_date_df['sponsor_class'] = cand_date_df['sponsors'].map(mapping_dict)
cand_date_df.head()
# Out:
#                          id  wp_identifier   network  \
# start_time
# 2016-08-01 01:19:59  261456           6035  FOXNEWSW
# 2016-08-01 06:20:04  261450           6035  FOXNEWSW
# 2016-08-01 08:39:49   48222           4176      WCAU
# 2016-08-01 08:48:14   48395           4176       KYW
# 2016-08-01 09:09:45  378441           7459    MSNBCW
#
#                                                location  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose, CA
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose, CA
# 2016-08-01 08:39:49                    Philadelphia, PA
# 2016-08-01 08:48:14                    Philadelphia, PA
# 2016-08-01 09:09:45  San Francisco-Oakland-San Jose, CA
#
#                                                    program program_type  \
# start_time
# 2016-08-01 01:19:59  On the Record With Greta Van Susteren         news
# 2016-08-01 06:20:04     Fox News Sunday With Chris Wallace         news
# 2016-08-01 08:39:49              NBC10 News Today at 430am         news
# 2016-08-01 08:48:14                 Eyewitness News at 430         news
# 2016-08-01 09:09:45                             First Look         news
#
#                              start_time            end_time  \
# start_time
# 2016-08-01 01:19:59 2016-08-01 01:19:59 2016-08-01 01:21:04
# 2016-08-01 06:20:04 2016-08-01 06:20:04 2016-08-01 06:21:09
# 2016-08-01 08:39:49 2016-08-01 08:39:49 2016-08-01 08:40:21
# 2016-08-01 08:48:14 2016-08-01 08:48:14 2016-08-01 08:48:46
# 2016-08-01 09:09:45 2016-08-01 09:09:45 2016-08-01 09:10:15
#
#                                      archive_id  \
# start_time
# 2016-08-01 01:19:59  PolAd_HillaryClinton_4drmd
# 2016-08-01 06:20:04  PolAd_HillaryClinton_4drmd
# 2016-08-01 08:39:49     PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14     PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  PolAd_HillaryClinton_4gvic
#
#                                                              embed_url  \
# start_time
# 2016-08-01 01:19:59  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 06:20:04  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 08:39:49  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  https://archive.org/embed/PolAd_HillaryClinton...
#
#                                     sponsors sponsor_types  race    cycle  \
# start_time
# 2016-08-01 01:19:59      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 06:20:04      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 08:39:49      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 08:48:14      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 09:09:45  Make America Number One     Super PAC  PRES 2,016.00
#
#                                                               subjects  \
# start_time
# 2016-08-01 01:19:59                                Candidate Biography
# 2016-08-01 06:20:04                                Candidate Biography
# 2016-08-01 08:39:49  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 08:48:14  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 09:09:45                                Candidate Biography
#
#                           candidates      type message        date_created  \
# start_time
# 2016-08-01 01:19:59  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 06:20:04  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 08:39:49     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 08:48:14     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 09:09:45  Hillary Clinton  campaign     con 2016-10-21 10:40:01
#
#                      ad_length day_of_week                      metro_area  \
# start_time
# 2016-08-01 01:19:59      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 06:20:04      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 08:39:49      32.00      Monday                    Philadelphia
# 2016-08-01 08:48:14      32.00      Monday                    Philadelphia
# 2016-08-01 09:09:45      30.00      Monday  San Francisco-Oakland-San Jose
#
#                         state  subject_count  hour_aired sponsor_class
# start_time
# 2016-08-01 01:19:59  National           1.00           1         R_PAC
# 2016-08-01 06:20:04  National           1.00           6         R_PAC
# 2016-08-01 08:39:49        PA           4.00           8       Clinton
# 2016-08-01 08:48:14        PA           4.00           8       Clinton
# 2016-08-01 09:09:45  National           1.00           9         R_PAC

# %%
cand_date_df.shape
# Out:
# (85127, 26)

# %%
cand_date_df['sponsor_class'].value_counts()
# Out:
# Clinton    37589
# Trump      22918
# D_PAC      14877
# R_PAC       7602
# Other       1778
# D_COM        206
# Johnson       82
# R_COM         72
# Stein          3
# Name: sponsor_class, dtype: int64

# %% [markdown]
# ## Creating the `party` feature
#
# - first going to limit the dataset to only the relevant sponsor classes to presidential election
# - filter out `Other` in `sponsor_class` which refers to non-presidential campaign organizations (e.g., Marco Rubio's PAC)

# %%
cand_date_df = cand_date_df[cand_date_df['sponsor_class'] != 'Other']
cand_date_df.head(2)
# Out:
#                          id  wp_identifier   network  \
# start_time
# 2016-08-01 01:19:59  261456           6035  FOXNEWSW
# 2016-08-01 06:20:04  261450           6035  FOXNEWSW
#
#                                                location  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose, CA
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose, CA
#
#                                                    program program_type  \
# start_time
# 2016-08-01 01:19:59  On the Record With Greta Van Susteren         news
# 2016-08-01 06:20:04     Fox News Sunday With Chris Wallace         news
#
#                              start_time            end_time  \
# start_time
# 2016-08-01 01:19:59 2016-08-01 01:19:59 2016-08-01 01:21:04
# 2016-08-01 06:20:04 2016-08-01 06:20:04 2016-08-01 06:21:09
#
#                                      archive_id  \
# start_time
# 2016-08-01 01:19:59  PolAd_HillaryClinton_4drmd
# 2016-08-01 06:20:04  PolAd_HillaryClinton_4drmd
#
#                                                              embed_url  \
# start_time
# 2016-08-01 01:19:59  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 06:20:04  https://archive.org/embed/PolAd_HillaryClinton...
#
#                                 sponsors sponsor_types  race    cycle  \
# start_time
# 2016-08-01 01:19:59  Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 06:20:04  Reform America Fund     Super PAC  PRES 2,016.00
#
#                                 subjects       candidates      type message  \
# start_time
# 2016-08-01 01:19:59  Candidate Biography  Hillary Clinton  campaign     con
# 2016-08-01 06:20:04  Candidate Biography  Hillary Clinton  campaign     con
#
#                            date_created  ad_length day_of_week  \
# start_time
# 2016-08-01 01:19:59 2016-09-21 10:40:12      65.00      Monday
# 2016-08-01 06:20:04 2016-09-21 10:40:12      65.00      Monday
#
#                                          metro_area     state  subject_count  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose  National           1.00
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose  National           1.00
#
#                      hour_aired sponsor_class
# start_time
# 2016-08-01 01:19:59           1         R_PAC
# 2016-08-01 06:20:04           6         R_PAC

# %%
cand_date_df.shape
# Out:
# (83349, 26)

# %%
# sanity check to ensure mask worked correctly - 1778

85127 - 83349
# Out:
# 1778

# %% [markdown]
# ### Using `map` and a `mapping dictionary` (`party_dict`) to create a new feature `party` from `sponsor_class`

# %%
cand_date_df['sponsor_class'].value_counts()
# Out:
# Clinton    37589
# Trump      22918
# D_PAC      14877
# R_PAC       7602
# D_COM        206
# Johnson       82
# R_COM         72
# Stein          3
# Name: sponsor_class, dtype: int64

# %%
party_dict = {'Clinton': 'D',
              'Trump': 'R',
              'D_PAC': 'D',
              'R_PAC': 'R',
              'D_COM': 'D',
              'Johnson': 'I',
              'R_COM': 'R',
              'Stein': 'I'
             }

# %%
# using map and 'party_dict'

cand_date_df['party'] = cand_date_df['sponsor_class'].map(party_dict)
cand_date_df.head()
# Out:
#                          id  wp_identifier   network  \
# start_time
# 2016-08-01 01:19:59  261456           6035  FOXNEWSW
# 2016-08-01 06:20:04  261450           6035  FOXNEWSW
# 2016-08-01 08:39:49   48222           4176      WCAU
# 2016-08-01 08:48:14   48395           4176       KYW
# 2016-08-01 09:09:45  378441           7459    MSNBCW
#
#                                                location  \
# start_time
# 2016-08-01 01:19:59  San Francisco-Oakland-San Jose, CA
# 2016-08-01 06:20:04  San Francisco-Oakland-San Jose, CA
# 2016-08-01 08:39:49                    Philadelphia, PA
# 2016-08-01 08:48:14                    Philadelphia, PA
# 2016-08-01 09:09:45  San Francisco-Oakland-San Jose, CA
#
#                                                    program program_type  \
# start_time
# 2016-08-01 01:19:59  On the Record With Greta Van Susteren         news
# 2016-08-01 06:20:04     Fox News Sunday With Chris Wallace         news
# 2016-08-01 08:39:49              NBC10 News Today at 430am         news
# 2016-08-01 08:48:14                 Eyewitness News at 430         news
# 2016-08-01 09:09:45                             First Look         news
#
#                              start_time            end_time  \
# start_time
# 2016-08-01 01:19:59 2016-08-01 01:19:59 2016-08-01 01:21:04
# 2016-08-01 06:20:04 2016-08-01 06:20:04 2016-08-01 06:21:09
# 2016-08-01 08:39:49 2016-08-01 08:39:49 2016-08-01 08:40:21
# 2016-08-01 08:48:14 2016-08-01 08:48:14 2016-08-01 08:48:46
# 2016-08-01 09:09:45 2016-08-01 09:09:45 2016-08-01 09:10:15
#
#                                      archive_id  \
# start_time
# 2016-08-01 01:19:59  PolAd_HillaryClinton_4drmd
# 2016-08-01 06:20:04  PolAd_HillaryClinton_4drmd
# 2016-08-01 08:39:49     PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14     PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  PolAd_HillaryClinton_4gvic
#
#                                                              embed_url  \
# start_time
# 2016-08-01 01:19:59  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 06:20:04  https://archive.org/embed/PolAd_HillaryClinton...
# 2016-08-01 08:39:49  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 08:48:14  https://archive.org/embed/PolAd_DonaldTrump_99k4w
# 2016-08-01 09:09:45  https://archive.org/embed/PolAd_HillaryClinton...
#
#                                     sponsors sponsor_types  race    cycle  \
# start_time
# 2016-08-01 01:19:59      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 06:20:04      Reform America Fund     Super PAC  PRES 2,016.00
# 2016-08-01 08:39:49      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 08:48:14      Hillary for America      Multiple  PRES 2,016.00
# 2016-08-01 09:09:45  Make America Number One     Super PAC  PRES 2,016.00
#
#                                                               subjects  \
# start_time
# 2016-08-01 01:19:59                                Candidate Biography
# 2016-08-01 06:20:04                                Candidate Biography
# 2016-08-01 08:39:49  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 08:48:14  Candidate Biography, Foreign Policy, Nuclear, ...
# 2016-08-01 09:09:45                                Candidate Biography
#
#                           candidates      type message        date_created  \
# start_time
# 2016-08-01 01:19:59  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 06:20:04  Hillary Clinton  campaign     con 2016-09-21 10:40:12
# 2016-08-01 08:39:49     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 08:48:14     Donald Trump  campaign   mixed 2016-09-12 14:51:51
# 2016-08-01 09:09:45  Hillary Clinton  campaign     con 2016-10-21 10:40:01
#
#                      ad_length day_of_week                      metro_area  \
# start_time
# 2016-08-01 01:19:59      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 06:20:04      65.00      Monday  San Francisco-Oakland-San Jose
# 2016-08-01 08:39:49      32.00      Monday                    Philadelphia
# 2016-08-01 08:48:14      32.00      Monday                    Philadelphia
# 2016-08-01 09:09:45      30.00      Monday  San Francisco-Oakland-San Jose
#
#                         state  subject_count  hour_aired sponsor_class party
# start_time
# 2016-08-01 01:19:59  National           1.00           1         R_PAC     R
# 2016-08-01 06:20:04  National           1.00           6         R_PAC     R
# 2016-08-01 08:39:49        PA           4.00           8       Clinton     D
# 2016-08-01 08:48:14        PA           4.00           8       Clinton     D
# 2016-08-01 09:09:45  National           1.00           9         R_PAC     R

# %%
all_df.shape, cand_date_df.shape
# Out:
# ((364718, 19), (83349, 27))

# %% [markdown]
# ## Pickling Dataframe - Sorted with Sponsors and Party Columns Added

# %%
# commenting out to prevent over-write -- it is in the data folder

# cand_date_df.to_pickle('data/pres_sorted_with_sponsors_and_party.pickle')

# %% [markdown]
# ## EDA | Cleaning | Feature Engineering Summary
#
# - limited dataset to presidential election and excluded dates outside of 8/1/16 - 11/8/16
#
# ### Created 8 new features:
#
# - `ad_length`
# - `day_of_week`
# - `metro_area`
# - `state`
# - `subject_count`
# - `hour_aired`
# - `sponsor_class`
# - `party`
#
# Created another feature `time_from_creation`, but later dropped it because it did not add value
#
# ### Further Cleaning / Feature Engineering in other Project 2 notebooks:
#
# - `data/pres_sorted_with_sponsors_and_party.pickle` is our primary cleaned dataset -- used as basis for `State_Daily_Ad_Counts_7DMA` and `State_Daily_Ad_Mix_by_Party_7DMA` time series analysis notebooks -- only further modified slightly in those notebook (removed NY observations -- see bullet point below)
#
#
# - Filtered out NY observations in `State_Daily_Ad_Counts_7DMA` pickled file as `data/political_tv_ads_cleaned_for_visuals.pickle` -- this is the basis for `Political_TV_Ads_Visualizations_April_21` notebook
#
#
# - created a counting dictionary of subjects to see which subjects were mentioned the most - see `subject_df` in `Political_TV_Ads_Visualizations_April_21` notebook
#
#
# - Time series data notebooks - `State_Daily_Ad_Counts_7DMA` and `State_Daily_Ad_Mix_by_Party_7DMA`
#
#
# - `State_Time_Series_Visualizations_April_21` makes use of pickled files from the Time Series data notebooks to generate visualizations (`data/state_party_ad_counts_7DMA.pickle` and `data/state_party_neg_ad_mix_7DMA.pickle`, respectively) -- also makes use of state poll data (`data/rcp_state_polls_amended.csv`)
